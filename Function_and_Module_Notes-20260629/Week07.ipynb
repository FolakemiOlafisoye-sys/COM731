# %% [markdown]
# # Functions and Modules

# %% [markdown]
# # Reference Books

# %% [markdown]
# - <font size="3">Fundametals of First Programs 2nd edition: Chapter 6</font>
# - <font size="3">Programming with Python: Module 9 and 13</font>

# %% [markdown]
# <font size="5">**Learning Objectives**</font><br>
# <font size="3">After this session, you should be able to:</font>
# - <font size="3">identify functions and function calls</font>
# - <font size="3">identify the arguments in a function call</font>
# - <font size="3">differentiate arguments from parameters</font>
# - <font size="3">code a function to work on particular task</font>
# - <font size="3">compose an assignment statement that collects a return value in a variable</font>
# - <font size="3">recognize when to use import versus from</font>
# - <font size="3">explain how to create a module in the same folder as another program</font>

# %% [markdown]
# ***

# %% [markdown]
# # Introduction

# %% [markdown]
# - <font size = "3"><b>Functions</b> are reusable blocks of code that perform specific tasks</font>
# - <font size ="3">A function packages an algorithm in a chunk of code that you can call by name</font>
# - <font size ="3">A function can be called from anywhere in a program’s code, including code within other functions</font>
# - <font size ="3">A function can receive data from its caller via <b>argument</b></font>
# - <font size ="3">When a function is called, any expression supplied as arguments are first evaluated</font>
# - <font size ="3">A function may have one or more <b>return</b> statements</font>

# %% [markdown]
# <font size="3">[Python Tutor: Visualize code in Python](https://pythontutor.com/visualize.html#mode=edit) demonstarte how the flow of function is executed</font>

# %% [markdown]
# - <font size="3">The function definition is <b>place before</b> your main code so that the interpreter knows what to do when it reaches the function call</font>
# - <font size="3"><b>Function structure:</b></font><br>
# &emsp;&emsp;&emsp;&emsp;<font size="3"> <span style="color: green;"><b>def</b></span> function_name<b>():</b><br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font size="3">sequence of statements-1<br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font size="3">sequence of statements-2<br>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<font size="3">...<br>

# %% [markdown]
# ### Programmer-defined functions Example

# %%
#Greeting message function
def welcome():
    print("Welcome to Solent University")
    print("Make Waves")

#Main program
welcome()
print("Program End")
# Out:
# Welcome to Solent University
# Make Waves
# Program End

# %%
# Write a program using functions to generate a table of a given number
number = int(input("Enter a number to generate the table for: "))

# function definition
def tbl(n): 
    for i in range(1, 11):
        mult = i * n
        print(f"{i} x {number} = {mult}")

tbl(number)
# Out:
# 1 x 11 = 11
# 2 x 11 = 22
# 3 x 11 = 33
# 4 x 11 = 44
# 5 x 11 = 55
# 6 x 11 = 66
# 7 x 11 = 77
# 8 x 11 = 88
# 9 x 11 = 99
# 10 x 11 = 110

# %%
# Write a program using functions to return the sum and product of 2 numbers
n1 = int(input("Enter the 1st number: "))
n2 = int(input("Enter the 2nd number: "))

# function definition
def multproduct(x,y):
    sm = x + y
    mlt = x * y
    return sm, mlt

# function calling
s, m = multproduct(n1,n2)
# function calling for 10
print(f"Sum of the numbers = {s}")
print(f"Product of the numbers = {m}")
# Out:
# Sum of the numbers = 5
# Product of the numbers = 6

# %% [markdown]
# ---

# %% [markdown]
# # Case Study: Calculating Final Marks
# - <font size=3>This case study focuses on building a function-based program to calculate a student's final mark for the module, which includes two assessments:</font>
#     - <font size=2>AE1: 40% of the total grade</font>
#     - <font size=2>AE2: 60% of the total grade</font>
# - <font size=3>The final mark is calculated by combining the weighted scores of both assessments.</font>
#     - <font size=2>For example, if a student scores 42 in AE1 and 35 in AE2, the calculation is:</font>
#          - <font size=2>(42 × 0.4) + (35 × 0.6) = 37.8</font>
#     - <font size=2>This result is then rounded to the nearest whole number, giving a final mark of 38</font>

# %% [markdown]
# ## Steps to Develop a Function-Based Program
# - <font size=3>Plan the Process</font>
#     - <font size=2>Think through the steps needed to calculate the total mark</font>
#     - <font size=2>Identify the required inputs: number of assessments, each assessment’s weight, and score.</font>
#     - <font size=2>Choose the suitable data type or collection to help the program run efficiently and handle data properly.</font>
# - <font size=3>Write a Simple Sequential Version</font>
#     - <font size=2>Implement the process in a basic, step-by-step format without using functions.</font>
#     - <font size=2>This helps test the logic and understand how the data flows.</font>
# - <font size=3>Identify Reusable Tasks</font>
#     - <font size=2>Look for parts of the code that perform a specific task (e.g., get assessment detail, calculating total mark).</font>
#     - <font size=2>These are good candidates to be turned into functions.</font>
# - <font size=3>Define Functions</font>
#     - <font size=2>Use def to define functions for each task.</font>
#     - <font size=2>Decide what parameters each function needs and what value it should return.</font>
# - <font size=3>Refactor the Code</font>
#     - <font size=2>Replace the repeated or specific logic in the sequential code with function calls.</font>
#     - <font size=2>This makes the program cleaner, easier to read, and reusable.</font>
# - <font size=3>Test and Improve</font>
#     - <font size=2>Run the program with different inputs to make sure it works correctly.</font>
#     - <font size=2>Adjust the functions or structure as needed for clarity or flexibility.</font>

# %% [markdown]
# -----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Simple Sequential Version

# %%
# Set intial variables
assessment_detail = {}
total_mark=0

# Get details of the assessments
num_assessments = int(input("Enter the number of asssessments: "))
for i in range(num_assessments):
    assessment_weight_mark = []
    type = input("Enter an assessment title [e.g. AE1, AE2]: ")
    weight = int(input("Enter weight of the assessment (e.g. 40, 60): "))
    weight_percentage = weight/100
    assessment_weight_mark.append(weight_percentage)
    assessment_mark = int(input(f"Enter your assessment mark for {type}: "))
    assessment_weight_mark.append(assessment_mark)
    assessment_detail[type.upper()] = assessment_weight_mark

# Calculate the total marks
for key, value in assessment_detail.items():
        print(f"Assessment {key}:")
        weight = value[0]
        score = value[1]
        mark = weight * score
        print(f"Mark for {key}: {mark}")
        total_mark = total_mark+mark

# Display the total mark
print(f"The total mark is : {round(total_mark)}")
# Out:
# Assessment AE1:
# Mark for AE1: 24.0
# Assessment AE2:
# Mark for AE2: 48.0
# The total mark is : 72

# %%
# Convert the simple code into modular or function based code
# Set intial variables
assessment_detail = {}

# Get details of the assessments
def  getting_details():
    num_assessments = int(input("Enter the number of asssessments: "))

    for i in range(num_assessments):
         assessment_weight_mark = []
         type = input("Enter an assessment title [e.g. AE1, AE2]: ")
         weight = int(input("Enter weight of the assessment (e.g. 40, 60): "))
         weight_percentage = weight/100
         assessment_weight_mark.append(weight_percentage)
         assessment_mark = int(input(f"Enter your assessment mark for {type}: "))
         assessment_weight_mark.append(assessment_mark)
         assessment_detail[type.upper()] = assessment_weight_mark

# Calculate the total marks
def calculate():
    total_mark=0
    for key, value in assessment_detail.items():
        print(f"Assessment {key}:")
        weight = value[0]
        score = value[1]
        mark = weight * score
        print(f"Mark for {key}: {mark}")
        total_mark = total_mark + mark

    return total_mark

# Display the total mark
def display(m):
    print(f"The total mark is : {round(total_mark)}")

# Calling the functions
# Calling getting_details function
getting_details()

# Calling calculate function
mark = calculate()

# Calling display function
display(mark)
# Out:
# Assessment AE1:
# Mark for AE1: 12.8
# Assessment AE2:
# Mark for AE2: 39.0
# The total mark is : 55

# %% [markdown]
# # Function, Parameters, Arguments and Return Values

# %% [markdown]
# ## Parameters

# %% [markdown]
# - <font size ="3"><b>A parameter</b> (also known as <b>a formal argument</b>) is an input to a function</font>
# - <font size ="3">Parameters allow us to pass information into functions</font>
# - <font size="3">Listed as variables inside parentheses at the end of the function name</font>

# %% [markdown]
# ## Arguments

# %% [markdown]
# - <font size ="3"><b>An argument</b> (also known as <b>an actual argument</b>) is data that is passed to a function</font>
# - <font size ="3">Python functions are invoked through call-by-object-reference - values are bound to objects and references to the objects are passed when a function is invoked</font>

# %% [markdown]
# ## Return values
# - <font size ="3">You can return data from a function using a <b><span style="color: green;">return</span></b> statement at the end of a function</font>
# - <font size ="3">Return value: data received by the main program from a function, which can be used for calculations or other operations</font>

# %% [markdown]
# ### Function, Parameters, Arguments, and Return Value Code

# %%
def calculate_mark(assessment_detail):
    total_mark = 0
    for key, value in assessment_detail.items():
        print(f"Assessment {key}:")
        weight = value[0]
        score = value[1]
        mark = weight * score
        print(f"Mark for {key}: {mark}")
        total_mark = total_mark+mark
    return total_mark

def get_assessment_detail(assessment_number):
    assessment_detail = {}
    for i in range(assessment_number):
        weight_mark = []
        type = input("Enter an assessment title [e.g. AE1, AE2]: ")
        weight_percentage = int(input("Enter weight of the assessment (e.g. 40, 60): "))
        weight = weight_percentage/100
        weight_mark.append(weight)
        assessment_mark = int(input(f"Enter your assessment mark for {type}: "))
        weight_mark.append(assessment_mark)
        assessment_detail[type.upper()] = weight_mark
    return assessment_detail


#Main Program
# Get assessment detial    
assessment_number = int(input("Enter a number of asssessment: "))
assessment_detail = get_assessment_detail(assessment_number)

# Calculate a total mark
total_mark = calculate_mark(assessment_detail)
        
# Display the total mark
print(f"The total mark is : {round(total_mark)}")
# Out:
# Assessment AE1:
# Mark for AE1: 14.4
# Assessment AE2:
# Mark for AE2: 40.8
# The total mark is : 55

# %% [markdown]
# # Define the Program’s Starting Point
# - <font size=3>To keep your program organised and easy to understand, it's a good practice to clearly separate the main execution part of your code.</font>
# - <font size=3>This ensures that the main part of your program only runs when the file is executed directly, not when it's imported as a module in another script. It helps make your code more reusable and easier to test.</font>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>if __name__ == "__main__"</b> <br>
#     <ul>
#         <li>Syntactically, Python’s if __name__ == "__main__" idiom is just a normal conditional block</li>
#         <li>It allows you to execute code when the file runs as a Script, but not when it’s imported as a Module</li>
#     </ul>
# </div>

# %%
def calculate_mark(assessment_detail):
    total_mark = 0
    for key, value in assessment_detail.items():
        print(f"Assessment {key}:")
        weight = value[0]
        score = value[1]
        mark = weight * score
        print(f"Mark for {key}: {mark}")
        total_mark = total_mark+mark
    return total_mark

def get_assessment_detail(assessment_number):
    assessment_detail = {}
    for i in range(assessment_number):
        weight_mark = []
        type = input("Enter an assessment title [e.g. AE1, AE2]: ")
        weight_percentage = int(input("Enter weight of the assessment (e.g. 40, 60): "))
        weight = weight_percentage/100
        weight_mark.append(weight)
        assessment_mark = int(input(f"Enter your assessment mark for {type}: "))
        weight_mark.append(assessment_mark)
        assessment_detail[type.upper()] = weight_mark
    return assessment_detail


#Main Program
if __name__ == "__main__":
    # Get assessment detial    
    assessment_number = int(input("Enter a number of asssessment: "))
    assessment_detail = get_assessment_detail(assessment_number)
    
    # Calculate a total mark
    total_mark = calculate_mark(assessment_detail)
        
    # Display the total mark
    print(f"The total mark is : {round(total_mark)}")
# Out:
# Assessment AE1:
# Mark for AE1: 13.600000000000001
# Assessment AE2:
# Mark for AE2: 43.199999999999996
# The total mark is : 57

# %% [markdown]
# ---

# %% [markdown]
# # Functions and File Handling
# - <font size=3>Case Study: Calculating Final Marks from a CSV File</font>
# - <font size=3>We’re working with a dataset for the COM731 module, which includes two assessments:</font>
#     - <font size=2>AE1 (40% weight)</font>
#     - <font size=2>AE2 (60% weight)</font>
# - <font size=3>The goal is to:</font>
#     - <font size=2>Read student data from a CSV file.</font>
#     - <font size=2>Calculate each student’s final mark using the assessment weights.</font>
#     - <font size=2>Round the final mark.</font>
#     - <font size=2>Determine if the student passes (mark ≥ 50) or fails.</font>

# %% [markdown]
# ## How the Program Works
# - <font size=3>Define Functions:</font>
#     - <font size=2>calculate_weighted_mark() to compute the final score.</font>
#     - <font size=2>check_pass() to determine pass/fail status.</font>
# - <font size=3>Read Data from File:</font>
#     - <font size=2>Use the csv module to read student records.</font>
# - <font size=3>Process Each Record:</font>
#     - <font size=2>For each student, calculate the final mark, round it, and check if they passed.</font>
# - <font size=3>Use if __name__ == "__main__":</font>
#     - <font size=2>This ensures the main logic runs only when the script is executed directly.</font>

# %%
import csv

# Function to calculate the weighted mark
def calculate_weighted_mark(ae1, ae2, weight_ae1=0.4, weight_ae2=0.6):
    return (ae1 * weight_ae1) + (ae2 * weight_ae2)

# Function to check pass/fail
def check_pass(mark, pass_mark=50):
    if mark >= pass_mark:
        result="Pass"
    else:
        result="Fail"
    return result

# Main program
if __name__ == "__main__":
    students_data = []
    while True:
        file_name = input("students.csv")
        try:
            # Read the data from the CSV file
            with open(file_name,encoding='utf-8') as file:
                reader = csv.reader(file)
                next(reader)  # Skip the header row
                for row in reader:
                    students_data.append(row)

            # Process each student's data
            for student in students_data:
                student_id = student[0]
                ae1 = float(student[1])
                ae2 = float(student[2])
                final_mark = calculate_weighted_mark(ae1, ae2)
                final_mark_rounded = round(final_mark)
                result = check_pass(final_mark_rounded)
                print(f"StudentID: {student_id}, Final Mark: {final_mark_rounded}, Result: {result}")
            
            break
        except FileNotFoundError:
            print("File not Found. Please try again.")
# Out:
# File not Found. Please try again.

# %% [markdown]
# -------------------------------------------------------------------------------------------

# %% [markdown]
# # Modules

# %% [markdown]
# - <font size ="3">A module is a Python file with a .py extension that contains functions and can be imported into another Python program</font>
# - <font size ="3">Python's default modules are stored in a certain location, but other modules can be stored in any location</font>
# - <font size ="3">Modules can be shared and utilised to allow developers to create solutions efficiently</font>
# - <font size ="3">You can bring module into a program as if you wrote them yourself</font>
# - <font size ="3">You use a keyword to tell Python which modules/parts of modules you want to include in your program</font>
# - <font size ="3">Modules are organised by purpose</font>

# %% [markdown]
# ## Importing Modules

# %% [markdown]
# - <font size ="3">We can bring in the module into the program using:</font>
#     - <font size ="3"><span style="color:green;">import</span></font>
#     - <font size ="3"><span style="color:green;">from</span></font>

# %% [markdown]
# ### import

# %% [markdown]
# - <font size ="3">Importing creating access to code from an external module</font>
# - <font size ="3">General syntax for importing</font>
#     - <font size ="3"><span style="color:green;"><b>import</b></span> [module_name] </font>
# - <font size ="3">It is often convenient to rename modules with abbreviated names in code using <span style="color:blue;">as</span> after module_name. This is particularly useful where we have long module names, or we are referring to sub-modules</font>

# %%
import random as rnd # importing random module and rename with abbreviated names

number = rnd.randrange(1,100) #Call function in the module [call function pattern:<module_name>.<function_name_in_the_module>]
print(f"Random number: {number}")
# Out:
# Random number: 66

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Importing an .ipynb file from another .ipynb file
# </div>
# <ul>
#     <li>Download .ipynb as Python(.py)</li>
#     <li>Upload .py file back into the same directory of your Jupyter Notebook file</li>
#     <li>import file as normal using import</li>
# </ul>

# %% [markdown]
# ### from

# %% [markdown]
# - <font size="3">Using <span style="color: green;">from</span> with <span style="color: green;">import</span> imports only the **specified** parts of a module and allows you to call imported functions without including the module name in the reference</font>
# - <font size="3">General syntax for importing:</font>
#     - <font size="2"><span style="color: green;">from</span> module_name <span style="color: green;">import</span> function_name</font>
# - <font size="3">Syntax to import multiple functions from a module:</font>
#     - <font size="2"><span style="color: green;">from</span> module_name <span style="color: green;">import</span> function_name1, function_name2</font>
# - <font size="3">Syntax to import all module items and reference them without the module name:</font>
#     - <font size="2"><span style="color: green;">from</span> module_name <span style="color: green;">import</span> <b>*</b></font>

# %%
#import math functions from math module for mathematical tasks.

from math import pow, sqrt, log10

#input x and y value
x= int(input("Enter the first number:"))
y = int(input("Enter the second number:"))

#pow() returns the value of x to the power of y
print(f"The value of {x} to the power of {y} is {pow(x,y)}")

#sqrt() returs the square root of a number
print(f"The square root of {x} is {sqrt(x)}")

#log10() returns the base-10 logarithm of x
print(f"The base-10 logarithm of {x} is {log10(x)}")
# Out:
# The value of 1 to the power of 2 is 1.0
# The square root of 1 is 1.0
# The base-10 logarithm of 1 is 0.0

# %% [markdown]
# click here to see more on [Python Math Module](https://www.w3schools.com/python/module_math.asp)

# %% [markdown]
# click here to see more on [Python Random Module](https://www.w3schools.com/python/module_random.asp)

# %% [markdown]
# # Creating Own Modules

# %% [markdown]
# - <font size="3">Create a Jupyter Notebook file and give it a descriptive name related to the module.</font>
# - <font size="3">In the notebook, write functions designed to perform specific tasks, ensuring they work towards a common purpose.</font>
# - <font size="3">Save the Jupyter Notebook file.</font>
# - <font size="3">Download the notebook as a Python script (.py)</font>
# - <font size="3">Move or upload the downloaded Python script (.py) to the same folder as your main program.</font>
# - <font size="3">Now, you can import your self-created module into another Python program.</font>

# %% [markdown]
# ## Summary

# %% [markdown]
# - <font size="3">A function serves as abstraction mechanism and eliminates redundant patterns of code</font>
# - <font size="3">A function hides a complex chunk of code in a single named entity</font>
# - <font size="3">A function consist of keyword ‘def’, function_name and zero, one, or a list of parameters</font>
# - <font size="3">A function can return none, one value, or multiple values</font>
# - <font size="3">Modules: pre-programmed pieces of code written by other programmers that you can bring into a program as if you wrote them yourself</font>

# %% [markdown]
# ---
