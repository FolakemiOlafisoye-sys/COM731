# %% [markdown]
# user_input

# %%
#Ask user to enter their name
print("What is your name human?")
name = input()
print(f"It is nice to meet you human {name}")
# Out:
# What is your name human?
# It is nice to meet you human Folakemi

# %%
# Amend your code to combine the first two statements into a single statement as follows:
# Read in a user's name
name = input("What is your name human?")

# %% [markdown]
# Data Type

# %%
#Calculate the BMI of a person
name = input("What is your name human?")
age = int(input("Enter your age in years: "))
weight = float(input("Enter your weight in kg: "))
height = float(input("Enter your height in m: "))

#The BMI calculation process
bmi = weight/(height*height)
print(f"{name}, you are {age} years old and your bmi is: {bmi:.2f}")
# Out:
# Folakemi, you are 22 years old and your bmi is: 29.59
