# %% [markdown]
# Activity: simple_dict

# %%
sequences = {'Short Sequece':3, 'Medium Sequence':2, 'Long Sequence':1}
print(f'Dictionary: ')
print(sequences)
# Out:
# Dictionary:
# {'Short Sequece': 3, 'Medium Sequence': 2, 'Long Sequence': 1}

# %% [markdown]
# Activity: iterate_dict

# %%
sequences = {'Short Sequece':3, 'Medium Sequence':2, 'Long Sequence':1}

print(sequences.keys())
print(sequences.values())
print(sequences)
# Out:
# dict_keys(['Short Sequece', 'Medium Sequence', 'Long Sequence'])
# dict_values([3, 2, 1])
# {'Short Sequece': 3, 'Medium Sequence': 2, 'Long Sequence': 1}
