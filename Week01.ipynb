# %%
print("Hello")
# Out:
# Hello

# %%
print("This is a simple script to demonstrate python execution")
# Out:
# This is a simple script to demonstrate python execution

# %% [markdown]
# Header

# %% [markdown]
# # Header 1

# %% [markdown]
# ## Header 2

# %% [markdown]
# ### Header 3
